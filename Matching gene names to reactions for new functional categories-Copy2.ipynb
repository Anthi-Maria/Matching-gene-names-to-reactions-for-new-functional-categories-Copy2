# %%
import numpy as np
import pandas as pd
import cobra.test
import os
from os.path import join

from time import time

a= cobra.io.read_sbml_model("iEC1344_C.xml")
# Out:
# Academic license - for non-commercial use only - expires 2023-02-21
# Using license file /home/schwartzlab/gurobi.lic

# %%
i= -1

J=list()
C=list()
J.append(a.genes[0].name)
C.append(a.genes[0].reactions)

dictionary = dict(zip(J, C))

dictionary
# Out:
# {'PhoE': frozenset({<Reaction 12PPDRtex at 0x7f2be0ff6850>,
#             <Reaction 12PPDStex at 0x7f2be0ff6d30>,
#             <Reaction 23CAMPtex at 0x7f2be0f84910>,
#             <Reaction 23CCMPtex at 0x7f2be0f84eb0>,
#             <Reaction 23CGMPtex at 0x7f2be0f84ca0>,
#             <Reaction 23CUMPtex at 0x7f2be0f84f10>,
#             <Reaction 23DAPPAtex at 0x7f2be0f84790>,
#             <Reaction 26DAHtex at 0x7f2be0f9be50>,
#             <Reaction 34dhpactex at 0x7f2be0f04ac0>,
#             <Reaction 3AMPtex at 0x7f2be0f04cd0>,
#             <Reaction 3CMPtex at 0x7f2be0f79430>,
#             <Reaction 3GMPtex at 0x7f2be0f0df10>,
#             <Reaction 3HPPtex at 0x7f2be0ebd8e0>,
#             <Reaction 3PEPTtex at 0x7f2be0eadeb0>,
#             <Reaction 3UMPtex at 0x7f2be0e40f40>,
#             <Reaction 3hoxpactex at 0x7f2bc5e2dc10>,
#             <Reaction 4HOXPACDtex at 0x7f2be0e40eb0>,
#             <Reaction 4PEPTtex at 0x7f2be0e54be0>,
# ...

# %%
i= -1

J=list()
C=list()
J.append(a.genes[0].name)
C.append(a.genes[0].reactions)

dictionary = dict(zip(J, C))

while i <1344:
   
    J= list()
    C= list()
    
    J.append(a.genes[i].name)
    C.append(a.genes[i].reactions)

    dictionary2 = dict(zip(J, C))
    dictionary.update(dictionary2)
    
    i=i+1

dictionary
# Out:
# {'PhoE': frozenset({<Reaction 12PPDRtex at 0x7f2be0ff6850>,
#             <Reaction 12PPDStex at 0x7f2be0ff6d30>,
#             <Reaction 23CAMPtex at 0x7f2be0f84910>,
#             <Reaction 23CCMPtex at 0x7f2be0f84eb0>,
#             <Reaction 23CGMPtex at 0x7f2be0f84ca0>,
#             <Reaction 23CUMPtex at 0x7f2be0f84f10>,
#             <Reaction 23DAPPAtex at 0x7f2be0f84790>,
#             <Reaction 26DAHtex at 0x7f2be0f9be50>,
#             <Reaction 34dhpactex at 0x7f2be0f04ac0>,
#             <Reaction 3AMPtex at 0x7f2be0f04cd0>,
#             <Reaction 3CMPtex at 0x7f2be0f79430>,
#             <Reaction 3GMPtex at 0x7f2be0f0df10>,
#             <Reaction 3HPPtex at 0x7f2be0ebd8e0>,
#             <Reaction 3PEPTtex at 0x7f2be0eadeb0>,
#             <Reaction 3UMPtex at 0x7f2be0e40f40>,
#             <Reaction 3hoxpactex at 0x7f2bc5e2dc10>,
#             <Reaction 4HOXPACDtex at 0x7f2be0e40eb0>,
#             <Reaction 4PEPTtex at 0x7f2be0e54be0>,
# ...

# %%
one= pd.read_csv("one feasible value reactions study conditions.csv")
flat= pd.read_csv("flat study conditions.csv")
diff_saturated= pd.read_csv("diff_saturated study conditions.csv")
Ushaped= pd.read_csv("Ushaped_reactions study conditions.csv")
monotonically_increasingANDstable_reactions= pd.read_csv("monotonically increasing and stable reactions study conditions.csv")
monotonically_increasing_only_reactions= pd.read_csv("monotonically increasing only reactions study conditions.csv")
monotonically_decreasingANDstable_reactions= pd.read_csv("monotonically decreasing and stable reactions study conditions.csv")
monotonically_decreasing_only_reactions= pd.read_csv("monotonically decreasing only reactions study conditions.csv")
increasingANDdecreasingANDstable_reactions= pd.read_csv("increasing and decreasing and stable reactions study conditions.csv")
increasingANDdecreasing_only_reactions= pd.read_csv("increasing and decreasing only reactions study conditions.csv")

# %%
import csv

with open('dictionary.csv', 'w') as f:  
    writer = csv.writer(f)
    for k, v in dictionary.items():
       writer.writerow([k, v])

# %%
import pandas as pd
p= pd.read_csv('dictionary.csv', header= None)
p

headerList= ["Gene name", "Reaction"]
p.to_csv("dictionary_NEW.csv", header=headerList, index=False)
p2 = pd.read_csv("dictionary_NEW.csv")
print('\nModified file:')
print(p2)
# Out:
# Modified file:
#        Gene name                                           Reaction
# 0           PhoE  frozenset({<Reaction LEUtex at 0x7f2be0f18070>...
# 1           YlbA  frozenset({<Reaction UGCIAMH at 0x7f2bc5cf4ca0>})
# 2           OmpC  frozenset({<Reaction LEUtex at 0x7f2be0f18070>...
# 3           OmpF  frozenset({<Reaction LEUtex at 0x7f2be0f18070>...
# 4           OmpN  frozenset({<Reaction LEUtex at 0x7f2be0f18070>...
# ...          ...                                                ...
# 1339        YcjT      frozenset({<Reaction MPL at 0x7f2bc5d45e80>})
# 1340        YafJ     frozenset({<Reaction ASNO at 0x7f2bc5d45fd0>})
# 1341        YgdH    frozenset({<Reaction PYRDC at 0x7f2bc5d5cd90>})
# 1342  Locus 3025  frozenset({<Reaction HPA3MOFAD at 0x7f2bc5d5cb...
# 1343        YcjM     frozenset({<Reaction SUCP at 0x7f2bc5d5cc70>})
#
# [1344 rows x 2 columns]

# %%
boolean_findings = p2['Reaction'].str.contains('UGCIAMH')

boolean_findings

i=0
gene_names= list()
while i <1343:
    if boolean_findings[i] ==True:
        
        l= p2.iloc[i, 0]
        gene_names.append(l)
    i=i+1
gene_names
# Out:
# ['YlbA']

# %%
diff_saturated["Reaction names"]
# Out:
# 0          EX_ppt_e
# 1          EX_fe2_e
# 2     ACOLIPAabctex
# 3               ADA
# 4               ADD
#           ...
# 87              POX
# 88              PPK
# 89              PPM
# 90    L_LACD2_copy2
# 91      XTSNH_copy2
# Name: Reaction names, Length: 92, dtype: object

# %%
z=0
saturated_gene_names= list()
l= str()

while z< len(diff_saturated):

    boolean_findings = p2['Reaction'].str.contains(diff_saturated["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            saturated_gene_names.append(l)
        i=i+1
    
    z=z+1

saturated_gene_names
# Out:
# ['LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'DdpX',
#  'GlyA',
#  'LtaE',
#  'PuuC',
#  'YehX',
#  'YehW',
#  'YehY',
#  'OsmF',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'CarA',
#  'CarB',
#  'ZntA',
#  'ZntA',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'ProP',
#  'CydD',
#  'CydC',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'ArtM',
#  'ArtJ',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'ArgT',
#  'ArtP',
#  'ArtI',
#  'ArtQ',
#  'FeoB',
#  'GlpA',
#  'GlpD',
#  'GlpB',
#  'GlpC',
#  'GlpA',
#  'GlpB',
#  'GlpC',
#  'GlpA',
#  'GlpB',
#  'GlpC',
#  'NadB',
#  'NadB',
#  'MglC',
#  'MglA',
#  'MglB',
#  'AspA',
#  'AspC',
#  'AspS',
#  'YtfR',
#  'YtfT',
#  'MglC',
#  'MglA',
#  'YjfF',
#  'YtfQ',
#  'MglB',
#  'YehX',
#  'YehW',
#  'YehY',
#  'OsmF',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'IdnD',
#  'ZntA',
#  'GhrB',
#  'GhrA',
#  'Dld',
#  'LptF',
#  'LptC',
#  'LptB',
# ...

# %%
z=0
one_gene_names= list()
l= str()

while z< len(one):

    boolean_findings = p2['Reaction'].str.contains(one['1 feasible value'][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            one_gene_names.append(l)
        i=i+1
    
    z=z+1

one_gene_names
# Out:
# ['PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LamB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FabA',
#  'FabZ',
#  'RutD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'MhpA',
#  'RffT',
#  'MalS',
#  'MhpA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LyxK',
#  'BglA',
#  'Prr',
#  'CpdB',
#  'CpdB',
# ...

# %%
z=0
flat_gene_names= list()
l= str()

while z< len(flat):

    boolean_findings = p2['Reaction'].str.contains(flat["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            flat_gene_names.append(l)
        i=i+1
    
    z=z+1

flat_gene_names
# Out:
# ['GhrB',
#  'GhrB',
#  'GhrB',
#  'GabP',
#  'FadA',
#  'AtoB',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'Acs',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Acs',
#  'EamA',
#  'EamB',
#  'GlcA',
#  'LldP',
#  'ActP',
#  'Add',
#  'LpxC',
#  'RffT',
#  'Ade',
#  'LigA',
#  'NudC',
#  'GlyA',
#  'LtaE',
#  'AlaA',
#  'AlaC',
#  'CycA',
#  'YaaJ',
#  'Adk',
#  'Adk',
#  'FeaB',
#  'Adk',
#  'RihC',
#  'Apt',
#  'MalQ',
#  'MalQ',
#  'MalQ',
#  'Amn',
#  'GltP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BetB',
#  'BisC',
#  'ChaA',
#  'YrbG',
#  'CaiC',
#  'ProP',
#  'CaiT',
#  'Add',
#  'CaiC',
#  'FadB',
#  'FadB',
#  'FadB',
#  'CueO',
#  'PtsH',
#  'PtsI',
#  'DhaK',
#  'DhaL',
#  'DhaM',
#  'DadA',
#  'FolB',
#  'PyrD',
#  'GhrB',
#  'GhrB',
#  'IspH',
#  'FabI',
#  'FabI',
#  'FabI',
#  'DsbB',
#  'DsbA',
#  'FabI',
#  'FabI',
#  'FabI',
# ...

# %%
z=0
Ushaped_gene_names= list()
l= str()

while z< len(Ushaped):

    boolean_findings = p2['Reaction'].str.contains(Ushaped["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            Ushaped_gene_names.append(l)
        i=i+1
    
    z=z+1

Ushaped_gene_names
# Out:
# ['GlyA',
#  'LtaE',
#  'KatE',
#  'KatG',
#  'Maa',
#  'IaaA',
#  'AnsA',
#  'AnsB',
#  'PurT',
#  'GltD',
#  'GltB',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'MgtA',
#  'NikC',
#  'NikE',
#  'NikD',
#  'NikB',
#  'NikA',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'NrfC',
#  'NrfD',
#  'NrfA',
#  'NrfB',
#  'NrfC',
#  'NrfD',
#  'NrfA',
#  'NrfB',
#  'PfkA',
#  'PfkB',
#  'PfkA',
#  'Prs',
#  'SodA',
#  'SodB',
#  'SodC',
#  'YbhA',
#  'CysU',
#  'CysA',
#  'CysP',
#  'Sbp',
#  'CysW',
#  'ModC',
#  'ModA',
#  'ZnuC',
#  'ZnuA',
#  'ZnuB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AcpP',
#  'PlsX',
#  'NudB',
#  'MutT',
#  'Cdh',
#  'GmhB',
#  'Ppx',
#  'Ppa',
#  'PutP',
#  'SurE']

# %%
z=0
monotonically_increasingANDstable_reactions_gene_names= list()
l= str()

while z< len(monotonically_increasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_increasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_increasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_increasingANDstable_reactions_gene_names
# Out:
# ['PyrD',
#  'DmsA',
#  'YnfH',
#  'DmsB',
#  'YnfE',
#  'YnfF',
#  'DmsC',
#  'YnfG',
#  'TorY',
#  'TorZ',
#  'TorY',
#  'TorZ',
#  'DmsA',
#  'DmsB',
#  'DmsC',
#  'TorY',
#  'TorZ',
#  'TorY',
#  'TorZ',
#  'DsbB',
#  'DsbA',
#  'PtsH',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'NarH',
#  'NarG',
#  'NarY',
#  'NarW',
#  'NarZ',
#  'NarV',
#  'NarI',
#  'NarJ',
#  'YgiN',
#  'DmsA',
#  'YnfH',
#  'DmsB',
#  'YnfE',
#  'YnfF',
#  'DmsC',
#  'YnfG',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'DmsA',
#  'DmsB',
#  'DmsC',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA']

# %%
z=0
monotonically_increasing_only_reactions_gene_names= list()
l= str()

while z< len(monotonically_increasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_increasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_increasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_increasing_only_reactions_gene_names
# Out:
# ['GhrB',
#  'ArgB',
#  'ArgA',
#  'AcpP',
#  'FabH',
#  'PurH',
#  'PurK',
#  'Adk',
#  'PurB',
#  'PurB',
#  'PurA',
#  'LpxB',
#  'Lpp',
#  'Lnt',
#  'Lpp',
#  'Lnt',
#  'PlsC',
#  'PlsC',
#  'PlsY',
#  'YdfG',
#  'PlsY',
#  'BetT',
#  'YeaV',
#  'BetB',
#  'BisC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YahI',
#  'YbcF',
#  'YqeA',
#  'CodB',
#  'ProP',
#  'PyrG',
#  'CusA',
#  'CusF',
#  'CusC',
#  'CusB',
#  'Dcd',
#  'CysM',
#  'CysK',
#  'CsdA',
#  'SelA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YiaK',
#  'AdiA',
#  'SpeA',
#  'FabI',
#  'FabI',
#  'YdfG',
#  'Eno',
#  'FabI',
#  'FabI',
#  'Fes',
#  'Fes',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'S0001',
#  'Fre',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'SsuE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AnsP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DctA',
#  'FhuF',
#  'AphA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NadB',
#  'PtsH',
# ...

# %%
z=0
monotonically_decreasingANDstable_reactions_gene_names= list()
l= str()

while z< len(monotonically_decreasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_decreasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_decreasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_decreasingANDstable_reactions_gene_names
# Out:
# ['DdpA',
#  'DdpB',
#  'DdpD',
#  'DdpC',
#  'DppF',
#  'DdpF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'AldB',
#  'GltJ',
#  'GltK',
#  'GltI',
#  'GltL',
#  'DctA',
#  'DcuA',
#  'DcuB',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'ProX',
#  'ProV',
#  'ProW',
#  'ProX',
#  'ProV',
#  'ProW',
#  'ProX',
#  'ProV',
#  'ProW',
#  'AppC',
#  'AppB',
#  'AppC',
#  'AppB',
#  'CydB',
#  'CydA',
#  'AraG',
#  'AraF',
#  'AraH',
#  'YdeA',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'SpeA',
#  'FbaA',
#  'MntH',
#  'FrdC',
#  'FrdB',
#  'FrdD',
#  'FrdA',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'GltJ',
#  'GltK',
#  'GltI',
#  'GltL',
#  'XanP',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'HisJ',
#  'YdeA',
#  'SetB',
#  'SetA',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'LivK',
#  'DcuA',
#  'DcuB',
#  'AcrD',
# ...

# %%
z=0
monotonically_decreasing_only_reactions_gene_names= list()
l= str()

while z< len(monotonically_decreasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_decreasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_decreasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_decreasing_only_reactions_gene_names
# Out:
# ['LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'NudJ',
#  'Cof',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'GabT',
#  'PuuE',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'PlsC',
#  'ArgC',
#  'AcpP',
#  'PlsX',
#  'PurE',
#  'AcpP',
#  'PlsX',
#  'CyaA',
#  'NudF',
#  'NudE',
#  'PlsC',
#  'PlsC',
#  'PlsC',
#  'PepB',
#  'PepA',
#  'PepN',
#  'PepD',
#  'PlsC',
#  'ApaH',
#  'LysU',
#  'PlsY',
#  'PlsY',
#  'PlsY',
#  'Cdh',
#  'S0001',
#  'PlsY',
#  'DppF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'PlsY',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ZupT',
#  'S0001',
#  'Cdh',
#  'Cdh',
#  'Cdh',
#  'Cdh',
#  'Cdh',
# ...

# %%
z=0
increasingANDdecreasingANDstable_reactions_gene_names= list()
l= str()

while z< len(increasingANDdecreasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(increasingANDdecreasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            increasingANDdecreasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

increasingANDdecreasingANDstable_reactions_gene_names
# Out:
# ['TalB',
#  'TalA',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'YdjI',
#  'FbaB',
#  'FbaA',
#  'NapG',
#  'NapA',
#  'NapC',
#  'NapB',
#  'NapH',
#  'MntH',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'FrdC',
#  'FrdB',
#  'FrdD',
#  'FrdA',
#  'CitE',
#  'CitF',
#  'CitD',
#  'CitX',
#  'PrpB',
#  'FdnI',
#  'FdnG',
#  'FdoI',
#  'FdnH',
#  'FdoG',
#  'FdoH',
#  'GlcD',
#  'GlcF',
#  'GlcE',
#  'PstA',
#  'PstB',
#  'PstS',
#  'PstC',
#  'GlcD',
#  'GlcF',
#  'GlcE']

# %%
z=0
increasingANDdecreasing_only_reactions_gene_names= list()
l= str()

while z< len(increasingANDdecreasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(increasingANDdecreasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            increasingANDdecreasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

increasingANDdecreasing_only_reactions_gene_names
# Out:
# ['AceB',
#  'GlcB',
#  'ZupT',
#  'CorA',
#  'CynT',
#  'Can',
#  'FabB',
#  'DdlA',
#  'DdlB',
#  'IdnK',
#  'GntK',
#  'Aas',
#  'ZupT',
#  'S0001',
#  'AqpZ',
#  'DeoD',
#  'Deleted',
#  'Rpe',
#  'YccX',
#  'GpsA',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'PurU',
#  'Aas',
#  'Adk',
#  'Ndk',
#  'YccX',
#  'Adk',
#  'Ndk',
#  'Tmk',
#  'Aas',
#  'GuaB',
#  'Deleted',
#  'DeoD',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'Gpt',
#  'FrlA',
#  'LysP',
#  'RihC',
#  'RihA',
#  'RihB',
#  'CdsA',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'GhrB',
#  'GhrA',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'Aas',
#  'GlpX',
#  'YggF',
#  'Fbp',
#  'YccX',
#  'XdhA',
#  'XdhB',
#  'XdhC',
#  'MpaA',
#  'Mdh',
#  'Mqo',
#  'AspC',
#  'Pck',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'PurN',
#  'Aas',
#  'MsbA',
# ...

# %%
Ushaped_gene_names = list( dict.fromkeys(Ushaped_gene_names) ) #remove duplicates in the list. I think that you convert it to dictionary and back to list (not sure)
one_gene_names = list( dict.fromkeys(one_gene_names) )
flat_gene_names = list( dict.fromkeys(flat_gene_names) )
saturated_gene_names = list( dict.fromkeys(saturated_gene_names) )
monotonically_increasingANDstable_reactions_gene_names = list( dict.fromkeys(monotonically_increasingANDstable_reactions_gene_names) )
monotonically_increasing_only_reactions_gene_names = list( dict.fromkeys(monotonically_increasing_only_reactions_gene_names) )
monotonically_decreasingANDstable_reactions_gene_names = list( dict.fromkeys(monotonically_decreasingANDstable_reactions_gene_names) )
monotonically_decreasing_only_reactions_gene_names = list( dict.fromkeys(monotonically_decreasing_only_reactions_gene_names) )
increasingANDdecreasingANDstable_reactions_gene_names = list( dict.fromkeys(increasingANDdecreasingANDstable_reactions_gene_names) )
increasingANDdecreasing_only_reactions_gene_names = list( dict.fromkeys(increasingANDdecreasing_only_reactions_gene_names) )

d1= pd.DataFrame(Ushaped_gene_names, columns= ["Gene names for Ushaped reactions"])
d2= pd.DataFrame(one_gene_names, columns= ["Gene names for reactions with one feasible value"])
d3= pd.DataFrame(flat_gene_names, columns= ["Gene names for flat reactions"])
d4= pd.DataFrame(saturated_gene_names, columns= ["Gene names for saturating reactions"])
d5= pd.DataFrame(monotonically_increasingANDstable_reactions_gene_names, columns= ["Gene names for increasing and stable reactions"])
d6= pd.DataFrame(monotonically_increasing_only_reactions_gene_names, columns= ["Gene names for increasing only reactions"])
d7= pd.DataFrame(monotonically_decreasingANDstable_reactions_gene_names, columns= ["Gene names for decreasing and stable reactions"])
d8= pd.DataFrame(monotonically_decreasing_only_reactions_gene_names, columns= ["Gene names for decreasing only reactions"])
d9= pd.DataFrame(increasingANDdecreasingANDstable_reactions_gene_names, columns= ["Gene names for increasing and decreasing and stable reactions"])
d10= pd.DataFrame(increasingANDdecreasing_only_reactions_gene_names, columns= ["Gene names for increasing and decreasing only reactions"])

csv_Ushaped_gene_names = d1.to_csv('Ushaped_gene_names study conditions.csv', index = True)
csv_one_gene_names = d2.to_csv('one_gene_names study conditions.csv', index = True) 
csv_flat_gene_names = d3.to_csv('flat_gene_names study conditions.csv', index = True)
csv_saturated_gene_names = d4.to_csv('saturated_gene_names study conditions.csv', index = True)
csv_monotonically_increasingANDstable_reactions_gene_names = d5.to_csv('monotonically_increasingANDstable_reactions_gene_names study conditions.csv', index = True)
csv_monotonically_increasing_only_reactions_gene_names = d6.to_csv('monotonically_increasing_only_reactions_gene_names study conditions.csv', index = True)
csv_monotonically_decreasingANDstable_reactions_gene_names = d7.to_csv('monotonically_decreasingANDstable_reactions_gene_names study conditions.csv', index = True)
csv_monotonically_decreasing_only_reactions_gene_names = d8.to_csv('monotonically_decreasing_only_reactions_gene_names study conditions.csv', index = True)
csv_increasingANDdecreasingANDstable_reactions_gene_names = d9.to_csv('increasingANDdecreasingANDstable_reactions_gene_names study conditions.csv', index = True)
csv_increasingANDdecreasing_only_reactions_gene_names = d10.to_csv('increasingANDdecreasing_only_reactions_gene_names study conditions.csv', index = True)
